# %%
def web_link_scrap(name,name_1,province):
    import requests
    from bs4 import BeautifulSoup as soup 
    import pandas as pd
    province = str(province)
    html = requests.get(str(name), headers={"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"})
    bsobj = soup(html.content,'lxml')
    links = []
    try:
        for review in bsobj.findAll('a',{'class':'Lwqic Cj b'}):
            a = review['href']
            a = 'tripadvisor.com'+ a
            a = a[:(a.find('Reviews')+100)] + '-or{}' + a[(a.find('Reviews')+100):]
            print(a)
            links.append(a)
    except Exception:
        pass
    
    df = pd.DataFrame(links)
    df.to_csv('0mining_' + str(name_1)+ '_' + province+'_res_tripadvisor.csv',encoding='utf-8-sig')

# %%
name = 'Pattaya'
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa30-Pattaya_Chonburi_Province.html','1',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa60-Pattaya_Chonburi_Province.html','2',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa90-Pattaya_Chonburi_Province.html','3',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa120-Pattaya_Chonburi_Province.html','4',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa150-Pattaya_Chonburi_Province.html','5',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa180-Pattaya_Chonburi_Province.html','6',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa210-Pattaya_Chonburi_Province.html','7',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa240-Pattaya_Chonburi_Province.html','8',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa270-Pattaya_Chonburi_Province.html','9',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa300-Pattaya_Chonburi_Province.html','10',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa330-Pattaya_Chonburi_Province.html','11',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa360-Pattaya_Chonburi_Province.html','12',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa390-Pattaya_Chonburi_Province.html','13',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa420-Pattaya_Chonburi_Province.html','14',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa450-Pattaya_Chonburi_Province.html','15',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa480-Pattaya_Chonburi_Province.html','16',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa510-Pattaya_Chonburi_Province.html','17',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa540-Pattaya_Chonburi_Province.html','18',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa570-Pattaya_Chonburi_Province.html','19',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa600-Pattaya_Chonburi_Province.html','20',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa630-Pattaya_Chonburi_Province.html','21',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa660-Pattaya_Chonburi_Province.html','22',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa690-Pattaya_Chonburi_Province.html','23',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa720-Pattaya_Chonburi_Province.html','24',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa750-Pattaya_Chonburi_Province.html','25',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa780-Pattaya_Chonburi_Province.html','26',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa810-Pattaya_Chonburi_Province.html','27',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa840-Pattaya_Chonburi_Province.html','28',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa870-Pattaya_Chonburi_Province.html','29',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa900-Pattaya_Chonburi_Province.html','30',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa930-Pattaya_Chonburi_Province.html','31',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa960-Pattaya_Chonburi_Province.html','32',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa990-Pattaya_Chonburi_Province.html','33',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1020-Pattaya_Chonburi_Province.html','34',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1050-Pattaya_Chonburi_Province.html','35',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1080-Pattaya_Chonburi_Province.html','36',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1110-Pattaya_Chonburi_Province.html','37',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1140-Pattaya_Chonburi_Province.html','38',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1170-Pattaya_Chonburi_Province.html','39',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1200-Pattaya_Chonburi_Province.html','40',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1230-Pattaya_Chonburi_Province.html','41',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1260-Pattaya_Chonburi_Province.html','42',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1290-Pattaya_Chonburi_Province.html','43',name)
web_link_scrap('https://www.tripadvisor.com/Restaurants-g293919-oa1320-Pattaya_Chonburi_Province.html','44',name)
# Out:
# th.tripadvisor.com/Restaurant_Review-g293919-d12283373-Reviews-Longhorn_Steakhouse_Grill-Pattaya_Chonburi_Province.html-or{}
# th.tripadvisor.com/Restaurant_Review-g293919-d3660931-Reviews-Bake_n_Brew-Pattaya_Chonburi_Province.html-or{}
# th.tripadvisor.com/Restaurant_Review-g293919-d2539959-Reviews-The_Sportsman_Pub_Restaurant-Pattaya_Chonburi_Province.html-or{}
# th.tripadvisor.com/Restaurant_Review-g293919-d3576181-Reviews-The_Coffee_Club_Royal_Garden_Plaza-Pattaya_Chonburi_Province.html-or{}
# th.tripadvisor.com/Restaurant_Review-g3366878-d23700619-Reviews-Wombat_Kiwi_Bar-Jomtien_Beach_Pattaya_Chonburi_Province.html-or{}
# th.tripadvisor.com/Restaurant_Review-g293919-d1636753-Reviews-Caprice_Restaurant_Bar-Pattaya_Chonburi_Province.html-or{}
# th.tripadvisor.com/Restaurant_Review-g293919-d7142883-Reviews-EL_Greco_Greek_and_mediterranean_restaurant-Pattaya_Chonburi_Province.html-or{}
# ...
