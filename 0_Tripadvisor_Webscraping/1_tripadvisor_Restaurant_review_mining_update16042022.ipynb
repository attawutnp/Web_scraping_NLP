# %% [markdown]
# # Function

# %%
def review_res_trip(name):
    import sys
    import csv
    from selenium import webdriver
    from webdriver_manager.chrome import ChromeDriverManager
    import time
    from selenium.common.exceptions import NoSuchElementException

    # number of scraped pages
    num_page = 100000

    #name = "th.tripadvisor.com/Restaurant_Review-g293919-d12643544-Reviews-Turkuaz_Turkish_Cafe_Restaurant_Pattaya-Pattaya_Chonburi_Province.html"
    # tripadvisor website of hotel or things to do (attraction/monument) 
    url = "https://" + str(name)

    # if you pass the inputs in the command line
    if (len(sys.argv) == 4):
        path_to_file = sys.argv[1]
        num_page = int(sys.argv[2])
        url = sys.argv[3]

    # import the webdriver
    driver = webdriver.Chrome(executable_path=ChromeDriverManager().install())
    driver.get(url)

    try:
        driver.find_element_by_class_name('evidon-banner-acceptbutton').click()
    except:
        pass 

    geolocation = ""

    title_text = str(driver.title)
    title_text_strip = title_text.replace(" - Menu, Prices & Restaurant Reviews - Tripadvisor","")
    title_text_strip = title_text.replace(" - Restaurant Reviews, Photos & Phone Number - Tripadvisor","")
    title_text_strip = title_text.replace("/","")
    
    print(title_text_strip)

    container = driver.find_elements_by_xpath(".//div[@class='review-container']")
    print(len(container))

    time.sleep(5)
    try:
        images = driver.find_elements_by_xpath(".//img[contains(@class,'mapImg')]")
        for image in images:
            geolocation = image.get_attribute('src')
    except:
        pass

    print(geolocation)

    path_to_file =  "output_review/mining_" + title_text_strip + ".csv"
    # open the file to save the review
    csvFile = open(path_to_file, 'a', encoding="utf-8-sig")
    csvWriter = csv.writer(csvFile)

    # change the value inside the range to save more or less reviews
    for i in range(0, num_page):

        # expand the review 
        time.sleep(2)
        #driver.find_element_by_xpath("//span[@class='taLnk ulBlueLinks']").click()
        try:
            driver.find_element_by_class_name('taLnk.ulBlueLinks').click()
        except:
            pass

        container = driver.find_elements_by_xpath(".//div[@class='review-container']")
        print(len(container))

        for j in range(len(container)):

            title = container[j].find_element_by_xpath(".//span[@class='noQuotes']").text
            date = container[j].find_element_by_xpath(".//span[contains(@class, 'ratingDate')]").get_attribute("title")
            rating = container[j].find_element_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]").get_attribute("class").split("_")[3]
            review = container[j].find_element_by_xpath(".//p[@class='partial_entry']").text.replace("\n", " ")

            csvWriter.writerow([date, rating, title, review, title_text_strip, geolocation]) 
        try:
            # change the page
            driver.find_element_by_xpath('.//a[@class="nav next ui_button primary"]').click()
        except:
            break

    driver.close()

# %% [markdown]
# # Set Variable

# %%
review_res_trip("tripadvisor.com/Restaurant_Review-g297935-d12711656-Reviews-Motana_Steak_Coffee-Rayong_Rayong_Province.html")

# %%
restaurant_name_list = [
"tripadvisor.com/Restaurant_Review-g297935-d10053607-Reviews-Kanghanlom_Restaurant-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10078705-Reviews-VT_Namnueng-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10127795-Reviews-Tuna_Ichiban-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10224869-Reviews-The_Lamian_by_KWAN-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10384440-Reviews-Thanyaros_Beef_Noodles-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10413676-Reviews-Wine_Connection_Passione_Rayong-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10519282-Reviews-Purple_Haze_Bar_Indian_Restaurant-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10722665-Reviews-Salada_Healthy_and_Bakery-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d10723009-Reviews-Ban_Ruen_Mai_Ngam_Resort_Restaurant-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d11618537-Reviews-Pond_Nam_Nueng-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d11621376-Reviews-J_Gallery_Rabbit_Cafe-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-d11798002-Reviews-Puan_E_San_Restaurant-Rayong_Rayong_Province.html",
"tripadvisor.com/Restaurant_Review-g297935-