# %% [markdown]
# # Function

# %%
def review_trip(name):
    import sys
    import csv
    from selenium import webdriver
    from webdriver_manager.chrome import ChromeDriverManager
    import time
    from selenium.common.exceptions import NoSuchElementException

    # number of scraped pages
    num_page = 100000

    # tripadvisor website of hotel or things to do (attraction/monument) 
    url = "https://" + str(name)

    # if you pass the inputs in the command line
    if (len(sys.argv) == 4):
        path_to_file = sys.argv[1]
        num_page = int(sys.argv[2])
        url = sys.argv[3]
    
    # import the webdriver
    driver = webdriver.Chrome(executable_path=ChromeDriverManager().install())
    driver.get(url)

    try:
        driver.find_element_by_class_name('evidon-banner-acceptbutton').click()
    except:
        pass 

    geolocation = ""

    title_text = str(driver.title)
    title_text_strip = title_text.replace(" - Prices & Reviews (Thailand) - Tripadvisor","")
    title_text_strip = title_text.replace("- Prices & Reviews - Thailand - Tripadvisor","")
    title_text_strip = title_text.replace("/","")
    

    print(title_text_strip)

    time.sleep(5)
    try:
        images = driver.find_elements_by_xpath(".//img[contains(@class,'ChASv')]")
        for image in images:
            geolocation = image.get_attribute('src')
    except:
        pass   

    print(geolocation)
    
    path_to_file =  "C:/Users/attawut/Documents/Web_scraping_NLP/0_Tripadvisor_Webscraping/1_output_review_res_ENG/mining_" + title_text_strip + ".csv"
    # open the file to save the review
    csvFile = open(path_to_file, 'a', encoding="utf-8-sig")
    csvWriter = csv.writer(csvFile)

    
    for i in range(0, num_page):

        # expand the review 
        time.sleep(5)
        try:
            driver.find_element_by_xpath(".//div[contains(@data-test-target, 'expand-review')]").click()
            time.sleep(5)

            container = driver.find_elements_by_xpath("//div[@data-reviewid]")
            print(len(container))
            dates = driver.find_elements_by_xpath(".//div[@class='bcaHz']")
            print(len(dates))

            for j in range(len(container)):
                time.sleep(5)
                rating = container[j].find_element_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_50')]").get_attribute("class").split("_")[3]
                title = container[j].find_element_by_xpath(".//div[contains(@data-test-target, 'review-title')]").text
                review = container[j].find_element_by_xpath(".//q[@class='XllAv H4 _a']").text.replace("\n", "  ")
                date = dates[j].text
                print(rating,title,review,date)

                csvWriter.writerow([date, rating, title, review, title_text_strip, geolocation]) 

            try:
                driver.find_element_by_xpath('.//a[@class="ui_button nav next primary "]').click()
            except:
                break
            time.sleep(5)
        except:
            break
    
    for i in range(0, num_page):

        # expand the review 
        time.sleep(5)
        try:
            driver.find_element_by_xpath(".//div[contains(@data-test-target, 'expand-review')]").click()
            time.sleep(5)

            container = driver.find_elements_by_xpath("//div[@data-reviewid]")
            print(len(container))
            dates = driver.find_elements_by_xpath(".//div[@class='bcaHz']")
            print(len(dates))

            for j in range(len(container)):
                time.sleep(5)
                rating = container[j].find_element_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]").get_attribute("class").split("_")[3]
                title = container[j].find_element_by_xpath(".//div[contains(@data-test-target, 'review-title')]").text
                review = container[j].find_element_by_xpath(".//q[@class='XllAv H4 _a']").text.replace("\n", "  ")
                date = dates[j].text
                print(rating,title,review,date)

                csvWriter.writerow([date, rating, title, review, title_text_strip, geolocation]) 

            try:
                driver.find_element_by_xpath('.//a[@class="ui_button nav next primary "]').click()
            except:
                break
            time.sleep(5)
        except:
            break
        
    driver.quit()

# %%
review_trip("tripadvisor.com/Restaurant_Review-g293919-d12283373-Reviews-Longhorn_Steakhouse_Grill-Pattaya_Chonburi_Province.html")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 103.0.5060
# Get LATEST driver version for 103.0.5060
# Driver [C:\Users\attawut\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# LONGHORN STEAKHOUSE & GRILL, Pattaya - Menu, Prices & Restaurant Reviews - Tripadvisor

# %% [markdown]
# # Set Variable

# %%
hotel_name_list = [
"tripadvisor.com/Hotel_Review-g293919-d8778814-Reviews-Himalayan_Inn-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8783977-Reviews-It_s_Me_Room_Bua_Khao-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8786096-Reviews-Brentwood_Manor-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8788232-Reviews-B_Space_Residence-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8789719-Reviews-Le_Trafalgar-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8789743-Reviews-Sleep_With_Love-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8790650-Reviews-Adam_s_Apple_Guest_House-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8793681-Reviews-The_Monttra_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8809888-Reviews-Kingfisher_House_Bar-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8817962-Reviews-J_E-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8818106-Reviews-Mai_Lu_Si_Guesthouse-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8818296-Reviews-Harry_s_Apartments_Bar_Restaurant-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8825176-Reviews-Chilling_Home-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8861042-Reviews-The_Sweet_Spot_Chocolate_Cafe-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8864405-Reviews-Patamnak_Beach_Guest_House-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8871454-Reviews-Villa_Simon_en_Villa_Anja-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8872637-Reviews-Modern_Place-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8873393-Reviews-Sutus_Court_2-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d8876002-Reviews-Ivory_Villa_City-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9105660-Reviews-Baan_Manow_Resort-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9111169-Reviews-Sea_Crest_by_Jomtien-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d911415-Reviews-Quality_Resort_at_Pattaya_Hill-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d940602-Reviews-Neta_Resort_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9451806-Reviews-Sabai_Living_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9451946-Reviews-P32_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9455263-Reviews-The_Pattaya_Inn-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9455412-Reviews-SleepCafe_Hostel-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9461326-Reviews-The_LD_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9464167-Reviews-Retox_Hotel-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9466016-Reviews-Luxury_Mini_Hotel_Angelheart-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9466024-Reviews-M_Place_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d951634-Reviews-The_BJ_Holiday_Lodge-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d952256-Reviews-Skaw_Beach_Hotel-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d952881-Reviews-Maitans_Guesthouse-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d953119-Reviews-Birds_and_Bees_Resort-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9596393-Reviews-A_D_Condominium_by_United_21_Thailand-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9601670-Reviews-Nova_Express_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9681467-Reviews-Sunshine_Hip_Hotel-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9697362-Reviews-Baan_Pattaya_Plus-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9701279-Reviews-Long_Beach_Pavilion_Luxury_Villas-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9723475-Reviews-La_Marina-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d972442-Reviews-Eurasia_Boutique_Hotel-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9741017-Reviews-Chitra_Suites-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9761492-Reviews-Kimhant_Apartment-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9761899-Reviews-Holidays_Home_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9762636-Reviews-LK_President-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9771207-Reviews-The_Hermitage-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9779379-Reviews-Aster_Hotel_And_Residence-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9779494-Reviews-Bua_Khao_Paradise_Guesthouse_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9785998-Reviews-Bobby_s_Place-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9787661-Reviews-Pook_Swan_House_Hotel-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9798883-Reviews-Sun_Shine_Coast_Inn-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9800986-Reviews-Montana-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9813946-Reviews-Datomas_Guest_House-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9861274-Reviews-Mera_Mare_Pattaya-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g293919-d9861639-Reviews-Garden_Guest_House-Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10061749-Reviews-True_Hostel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10137331-Reviews-Jomtien_Hisotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10158596-Reviews-The_Victoria_Resort_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10166152-Reviews-The_Rin_Boutique_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10174714-Reviews-Aitalay_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10265470-Reviews-Baptist_Conference_Center_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10270684-Reviews-Tiya_s_Place-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10413296-Reviews-Inn_Residence_Serviced_Suites-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10441800-Reviews-See_also_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10446926-Reviews-Petchpanee_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10623612-Reviews-Sweet_Sense_Jomtien_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10803432-Reviews-Siam_Wave-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10822307-Reviews-Everybody_s_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d10901291-Reviews-Excellence_Corner-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1102337-Reviews-Villa_Thongbura-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d11435791-Reviews-P_P_Jomtien_Beach-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d11436999-Reviews-Arbani_Seaview-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d11443588-Reviews-Auddie_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1160052-Reviews-Sea_Breeze_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1174555-Reviews-Sarita_Chalet_and_Spa-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12001826-Reviews-W1A_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12095384-Reviews-Achada_Beach_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12103517-Reviews-Dragon_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12124974-Reviews-Jomtien_Sunset_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12125804-Reviews-Ibiza_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12125822-Reviews-Paradise_Garden_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12141359-Reviews-OYO_1099_Star_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12157538-Reviews-The_Sala_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12169933-Reviews-The_Pat_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12170083-Reviews-OYO_419_Maleewan_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12172277-Reviews-Innova_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12185963-Reviews-Chanisa_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12253841-Reviews-Jomtien_Luxury_Rooms-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12255453-Reviews-Taimei_Guest_House_Jomtien_Metro_Condotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12277045-Reviews-Anna_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12296339-Reviews-LawinTa_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12317549-Reviews-Devika_Fe-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12336022-Reviews-K_J_Apartment-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12432408-Reviews-Chang_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12494508-Reviews-J_K_guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12544291-Reviews-Lom_Thalay_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12562450-Reviews-Baan_der_Bruyn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12579848-Reviews-Breezy_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12596364-Reviews-Melissa_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12640678-Reviews-My_Restaurant_and_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12822006-Reviews-Siam_Sea_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12824845-Reviews-Love_Antiques_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12929447-Reviews-The_Mangrove_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12945311-Reviews-Siamcats_Guesthouse_Bar-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12975734-Reviews-Golden_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d12996117-Reviews-White_Sand_Beach_Residences-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13007998-Reviews-Baan_Talay_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13087018-Reviews-Jairanai_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13101785-Reviews-Nalinda_Hotel_Cafe-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13121454-Reviews-Baanmae_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13164953-Reviews-Sonia_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13194898-Reviews-Abani_Jomtien_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13320551-Reviews-Kontiki_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13326580-Reviews-J_P_S_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13339636-Reviews-OYO_348_Saithong_Place-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13368699-Reviews-Sanuk_Sabai_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13368734-Reviews-Me_Dee_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13390473-Reviews-Sea_Sun-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13413698-Reviews-Bee_Sleep_Hostel_Nana_Art_gallery-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13425043-Reviews-Happy_Bou_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13432137-Reviews-Sunlight_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13432663-Reviews-Golden_Parsley-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13443846-Reviews-Pergola_Jhomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13446163-Reviews-Simple_Simon-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13496605-Reviews-Adare_Garden_Pool_Villas_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13798135-Reviews-JN9_Poshtel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13866642-Reviews-Hotel_Dacha-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d13954286-Reviews-Seven_Seas_Condo_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d14167667-Reviews-Atlantis_Condo_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1475458-Reviews-Jomtien_Hostel_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d14787125-Reviews-Giant_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d14863371-Reviews-Soi_5_Poshtel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d14917367-Reviews-Monoroom-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15049563-Reviews-Our_Place-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15220083-Reviews-Welcome_Everybody-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15288645-Reviews-BB_House_Beach_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1531865-Reviews-Casaviva_Inn_Hotel_and_Condominiums-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15334987-Reviews-Nam_Talay_Jomtien_Beach-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15516002-Reviews-Ruamchok_Ocean_View-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15593695-Reviews-Achawalai_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15638400-Reviews-Park_Lane_And_Paradise_Park_Apartments-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1566943-Reviews-Isawanya_Beach_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15680912-Reviews-Seven_Seas_Condo_by_Dmitrii-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15730813-Reviews-Sea_View_Beachfront_Condos_Pattaya_Jomtien_Beach-Jomtien_Beach_Pattaya_Chonburi_Prov.html",
"tripadvisor.com/Hotel_Review-g3366878-d15734289-Reviews-Atlantic_Condo_Resort_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15809011-Reviews-Lumpini_Park_Beach_Jomtien_Sea_View-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d15841707-Reviews-Jomtien_Beach_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16711131-Reviews-Malinitour_Apartments-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16714851-Reviews-Baan_Suan_Lalana-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16737297-Reviews-Lovely_Condo-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16740833-Reviews-La_Santir_Chaiyapruek-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16760608-Reviews-Indogee_Apartments-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16766115-Reviews-Paradise_Park-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16812938-Reviews-The_Gallery_Condominium-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d16835534-Reviews-Amazon_Residence_Condominimum_Flats-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17531279-Reviews-Cu_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17559204-Reviews-Atlantis_Athena_Condominium_Resort_By_Shah-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17596739-Reviews-Jomtien_Hostel_3-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17667263-Reviews-Laguna_Beach_Resort_3_Maldives-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17677088-Reviews-Porchland_2_Jomtien_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17678506-Reviews-Park_Lane_Apartments_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17697224-Reviews-Jin_Xiao_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d17803818-Reviews-Princess_Pool_Villa_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1793595-Reviews-Inrawadee_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1816939-Reviews-The_Venue_Residence_Cabaret-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1913207-Reviews-Beach_Net_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d1935982-Reviews-Royal_Thai_Pavilion_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d19453515-Reviews-Premium_Pool_Villa_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d20699817-Reviews-White_House_Pool_Villa_By_ShriGo_Hotels-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d20804594-Reviews-Neo_Seaview_Condo_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d20896693-Reviews-Baan_Nam_Tarn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d20896814-Reviews-Porntippa_Tipppawan_House_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d20907780-Reviews-Taimei_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d20952331-Reviews-Paramita_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21313575-Reviews-View_Talay_7_Jomtien_Beach_Condominium-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21328819-Reviews-Furnished_Apartments_By_Neang-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21336976-Reviews-White_House_Pool_Villa_by_Asapian_Hotels-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21345824-Reviews-Sands_802_Pratamnak-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21351302-Reviews-Patricia_Suite-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21368467-Reviews-Ons_Moeder-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21372742-Reviews-Atlantis_Condo_Resort_By_Amantara_Gruop-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21373356-Reviews-Espana_Condo_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21391345-Reviews-Lumpini_Jomtien_Beach_Pattaya_by_Bluesky-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21396357-Reviews-ESPANA_Pattaya_by_Plearn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21396781-Reviews-Amazon_by_Amonwan-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21397315-Reviews-Maldives_Laguna_Beach_Resort_3-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21400613-Reviews-Favstay_The_Grand_Jomtien_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d21403549-Reviews-Seven_Seas_Bounty-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d22843707-Reviews-Maldives_Pattaya_Laguna3-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d2289097-Reviews-Jomtien_Beach_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23206981-Reviews-Tkag_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23210092-Reviews-OYO_1141_Ban_Dao_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23328241-Reviews-Riviera_Jomtien_by_Pattaya_Paradise-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23357482-Reviews-Jomtien_Apartment_2_bedroom_NEO_Condo_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23403224-Reviews-Acqua_Condominium_by_Kp-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23432881-Reviews-Coucher_de_Soleil_les_Pieds_Dan_s_L_eau_c_Est_Trop_Beau-Jomtien_Beach_Pattaya_Chonbu.html",
"tripadvisor.com/Hotel_Review-g3366878-d23524689-Reviews-See_the_Sea_Grand_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d2356720-Reviews-Euro_Asia_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23652546-Reviews-Wanneepachok_resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23879614-Reviews-OYO_75384_By_Dee_jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23928599-Reviews-RedDoorz_By_Dee_Jomtien_Beach_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d23960443-Reviews-The_NG_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3324662-Reviews-Your_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3522282-Reviews-Blue_Garden_Resort_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3569216-Reviews-High_Lords_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3819738-Reviews-Sunny_Beach_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3877255-Reviews-Beachwalk_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3878974-Reviews-Twenty_8_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d3930187-Reviews-Jomtien_Little_Mango_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d4049533-Reviews-Sun_Sky_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d4078946-Reviews-Happy_Valley_Apartment-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d4239196-Reviews-Teremok-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d4355390-Reviews-Lek_Jomtien_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d4761803-Reviews-Welcome_Marina-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d4843959-Reviews-Cold_Rock-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d5928909-Reviews-Vickans_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d5967012-Reviews-Artem_s_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d5986804-Reviews-B2_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6033693-Reviews-Tevan_Jomtien_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6205967-Reviews-M1_Boutique-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6350989-Reviews-Sunshine_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6411925-Reviews-Guesthouse_Joy_Peter_Cap-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6428727-Reviews-Sweet_Heart_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d643077-Reviews-Nirvana_Boutique_Suites-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6521034-Reviews-Lumpini_Park_Beach_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6595359-Reviews-Inn18-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6621304-Reviews-Apartment_Friendly_Jomtien_Plaza_Condotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d674161-Reviews-D_Varee_Jomtien_Beach_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6772842-Reviews-Hotel_Avenue_Inn-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6772860-Reviews-Bamboos_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d6925402-Reviews-Sunshine_Beach_Condotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7052649-Reviews-Lemon_Grass_Retreat-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7130913-Reviews-Fat_Cat-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7183399-Reviews-Thai_Orange_Duo-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7305335-Reviews-Lighthouse_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7306844-Reviews-I_Talay_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7307064-Reviews-Tribe_Hotel_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7318130-Reviews-Good_Luck_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7384064-Reviews-Christie_Mu_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7399047-Reviews-Honey_House_3-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7593047-Reviews-Cowboy_Farm_Resort_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7646207-Reviews-Joy_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7660515-Reviews-Wanida_s_Room_For_Rent-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7767493-Reviews-D_Sea_Hotel-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7813426-Reviews-Boss_Bar-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7814833-Reviews-My_Dream_House_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7903461-Reviews-Z_by_Zing-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d7985983-Reviews-Elle_s_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d808279-Reviews-Pinnacle_Grand_Jomtien_Resort-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8300081-Reviews-Concordia_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8327532-Reviews-Jomtien_Beach_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8336474-Reviews-By_Dee_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8442591-Reviews-Chida_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8480143-Reviews-101_Holiday_Suite-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8730424-Reviews-Your_Friend-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8787976-Reviews-Key_Bar_and_Guest_House-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8816256-Reviews-Guest_House_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d8867424-Reviews-Royal_Heritage_Pavilion_Jomtien-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d9463224-Reviews-Veranda_Resort_Pattaya_Na_Jomtien_MGallery-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d9698483-Reviews-BarFly_Pattaya-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d9808391-Reviews-The_Circle_Residence-Jomtien_Beach_Pattaya_Chonburi_Province.html",
"tripadvisor.com/Hotel_Review-g3366878-d9832251-Reviews-Jomtien_Beach_Guesthouse-Jomtien_Beach_Pattaya_Chonburi_Province.html",

]

len(hotel_name_list)
# Out:
# 263

# %% [markdown]
# # Run Function

# %%
for index, elem in enumerate(hotel_name_list):
    print(index, elem)
    review_trip(elem)
    print("Finish",elem)
# Out:
# 0 tripadvisor.com/Hotel_Review-g293919-d8778814-Reviews-Himalayan_Inn-Pattaya_Chonburi_Province.html
# /tmp/ipykernel_1257611/1570259007.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name('evidon-banner-acceptbutton').click()
# HIMALAYAN INN - Condominium Reviews (Pattaya, Thailand)
# /tmp/ipykernel_1257611/1570259007.py:42: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath(".//img[contains(@class,'ChASv')]")
# ...
